# %%
import math
import cmath
import matplotlib.pyplot as plt

# %%
real = -1 * math.sqrt(0)
imaginary = 1 * math.sqrt(2)
z = complex(real, imaginary)

# %%
print(z)
# Out:
# (-0+1.4142135623730951j)

# %%
z2 = 3 + 4j
z2
# Out:
# (3+4j)

# %%
z4 = z2 * z2
print(z4)
# Out:
# (-7+24j)

# %%
z4.real
# Out:
# -7.0

# %%
z4.imag
# Out:
# 24.0

# %%
print(z.imag)
z.imag * z.imag
# Out:
# 1.4142135623730951
# 2.0000000000000004

# %%
print(z)
z3 = z * z
z3
# Out:
# (-0+1.4142135623730951j)
# (-2.0000000000000004-0j)

# %%
cmath.phase(z)
# Out:
# 1.5707963267948966

# %%
numbers = []
for i in range(5):
    for j in range(5):
        numbers.append(complex(i,j))
        
len(numbers)
# Out:
# 25

# %%
numbers
# Out:
# [0j,
#  1j,
#  2j,
#  3j,
#  4j,
#  (1+0j),
#  (1+1j),
#  (1+2j),
#  (1+3j),
#  (1+4j),
#  (2+0j),
#  (2+1j),
#  (2+2j),
#  (2+3j),
#  (2+4j),
#  (3+0j),
#  (3+1j),
#  (3+2j),
#  (3+3j),
#  (3+4j),
#  (4+0j),
#  (4+1j),
#  (4+2j),
#  (4+3j),
#  (4+4j)]

# %%
z = complex(10, 10)
y = complex(2, 4)
x = z - y

numbers = [x, y, z]

for x in numbers:
    r, phi = cmath.polar(x)
    plt.polar([0, phi],[0, r], marker='o')
    print(x)
# Out:
# (8+6j)
# (2+4j)
# (10+10j)

# %%
complex_numbers = [
    complex(1,1), 
    complex(2,1), 
    complex(6,3), 
    complex(-3,4), 
    complex(6,-1)
]

# %%
total = complex(0, 0)
for complex_number in complex_numbers:
    total = complex_number + total

# %%
total
# Out:
# (12+8j)

# %%
total2 = complex(0, 0)
output = [total2 := total2 + c for c in complex_numbers]
total2
# Out:
# (12+8j)

# %%
for x in complex_numbers:
    r, phi = cmath.polar(x)
    plt.polar([0, phi],[0, r], marker='o')
    print(x)
# Out:
# (1+1j)
# (2+1j)
# (6+3j)
# (-3+4j)
# (6-1j)
